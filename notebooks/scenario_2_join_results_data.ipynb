# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ls ../results
# Out:
# 1#_results.json               hyperp_data_frequency_4.json  results_17-20.json
# graphic_results/              hyperp_data_frequency_5.json  results_21-24.json
# hyperp_data_frequency_0.json  hyperp_data_frequency_6.json  results_25-28.json
# hyperp_data_frequency_1.json  hyperp_data_frequency_7.json  results_29-30.json
# hyperp_data_frequency_2.json  results_13-16.json            results_5-8.json
# hyperp_data_frequency_3.json  results_1-4.json              results_9-12.json

# %%
data1 = pd.read_json("../results/results_1-4.json")
data2 = pd.read_json("../results/results_5-8.json")
data3 = pd.read_json("../results/results_9-12.json")
data4 = pd.read_json("../results/results_13-16.json")
data5 = pd.read_json("../results/results_17-20.json")
data6 = pd.read_json("../results/results_21-24.json")
data7 = pd.read_json("../results/results_25-28.json")
data8 = pd.read_json("../results/results_29-30.json")

# %%
final_df = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8])

# %%
final_df
# Out:
#     exec   seed         station  \
# 0      1   1551  Bobo Dioulasso
# 1      1   1551          Boromo
# 2      1   1551    Bur Dedougou
# 3      1   1551            Dori
# 4      1   1551   Fada N'gourma
# ..   ...    ...             ...
# 11    30  47400            Dori
# 12    30  47400   Fada N'gourma
# 13    30  47400           Gaoua
# 14    30  47400      Ouahigouya
# 15    30  47400              Po
#
#                                           best params  best score  \
# 0   {'features_select__k': 300, 'poly_features__de...   -0.588787
# 1   {'features_select__k': 300, 'poly_features__de...   -0.657792
# 2   {'features_select__k': 300, 'poly_features__de...   -0.594595
# 3   {'features_select__k': 210, 'poly_features__de...   -2.979427
# 4   {'features_select__k': 300, 'poly_features__de...   -0.547988
# ..                                                ...         ...
# 11  {'features_select__k': 180, 'poly_features__de...   -2.984309
# ...

# %%
final_df.reset_index(inplace=True, drop=True)

# %%
final_df
# Out:
#      exec   seed         station  \
# 0       1   1551  Bobo Dioulasso
# 1       1   1551          Boromo
# 2       1   1551    Bur Dedougou
# 3       1   1551            Dori
# 4       1   1551   Fada N'gourma
# ..    ...    ...             ...
# 235    30  47400            Dori
# 236    30  47400   Fada N'gourma
# 237    30  47400           Gaoua
# 238    30  47400      Ouahigouya
# 239    30  47400              Po
#
#                                            best params  best score  \
# 0    {'features_select__k': 300, 'poly_features__de...   -0.588787
# 1    {'features_select__k': 300, 'poly_features__de...   -0.657792
# 2    {'features_select__k': 300, 'poly_features__de...   -0.594595
# 3    {'features_select__k': 210, 'poly_features__de...   -2.979427
# 4    {'features_select__k': 300, 'poly_features__de...   -0.547988
# ..                                                 ...         ...
# 235  {'features_select__k': 180, 'poly_features__de...   -2.984309
# ...

# %%
final_df.to_json("../results/2#_results.json")

# %%
ls ../results
# Out:
# 1#_results.json               hyperp_data_frequency_4.json  results_21-24.json
# 2#_results.json               hyperp_data_frequency_5.json  results_25-28.json
# graphic_results/              hyperp_data_frequency_6.json  results_29-30.json
# hyperp_data_frequency_0.json  hyperp_data_frequency_7.json  results_5-8.json
# hyperp_data_frequency_1.json  results_13-16.json            results_9-12.json
# hyperp_data_frequency_2.json  results_1-4.json
# hyperp_data_frequency_3.json  results_17-20.json
